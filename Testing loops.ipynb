# %%
from pprint import pprint
import pandas as pd
import datetime as dt

# %% [markdown]
# ## Daily loop with hours embedded

# %%
for m in range(1, 13):
    year = 2021
    yearAfter = year
    monthBefore = m
    monthAfter = m
        
    day = 32
    
    if (m == 2):
        day = 29
    if (m == 4) or (m == 6) or (m == 9) or (m == 11):
        day = 31
    
    for d in range(1, day):
        # loop through the dates :TODO

        # date variables
        dayBefore = d
        dayAfter = d-1

        # if current day is 1, then the previous day is the last day in previous month
        if(dayAfter == 0):
            monthAfter = m-1
            if(m == 2):
                dayAfter = 31
            elif(m==3):
                dayAfter = 28
            elif (m == 4) or (m == 6) or (m == 9) or (m == 11):
                dayAfter = 31
            else: dayAfter = 30
        else: monthAfter = m
            

        if(monthAfter == 0):
            monthAfter = 12
            yearAfter = year-1
        else: yearAfter = year

    before = dt.datetime(year,monthBefore,dayBefore,0,0)
    after = dt.datetime(yearAfter,monthAfter,dayAfter,0,0)
      
#         for h in range(24):

#             hourBefore = h
#             hourAfter = h + 1
#             minutes = 0
            
#             if (hourAfter == 24):
#                 hourAfter = 23
#                 minutes = 59

#             # add an hour to the datetime object
#             scrapeHourDateBefore = dt.datetime(year,monthBefore,dayBefore,hourBefore,0)
#             scrapeHourDateAfter = dt.datetime(yearAfter,monthAfter,dayAfter,hourAfter,minutes)
            
#             scrapeHourDateBefore = int(dt.datetime(year,monthBefore,dayBefore,hourBefore,0).timestamp())
#             scrapeHourDateAfter = int(dt.datetime(yearAfter,monthAfter,dayAfter,hourAfter,minutes).timestamp())


            #set time frame for scraping -> hourly
            
    print('date after', after)
    print('date before', before)
# Out:
# date after 2021-01-30 00:00:00
# date before 2021-01-31 00:00:00
# date after 2021-02-27 00:00:00
# date before 2021-02-28 00:00:00
# date after 2021-03-30 00:00:00
# date before 2021-03-31 00:00:00
# date after 2021-04-29 00:00:00
# date before 2021-04-30 00:00:00
# date after 2021-05-30 00:00:00
# date before 2021-05-31 00:00:00
# date after 2021-06-29 00:00:00
# date before 2021-06-30 00:00:00
# date after 2021-07-30 00:00:00
# date before 2021-07-31 00:00:00
# date after 2021-08-30 00:00:00
# date before 2021-08-31 00:00:00
# date after 2021-09-29 00:00:00
# date before 2021-09-30 00:00:00
# date after 2021-10-30 00:00:00
# date before 2021-10-31 00:00:00
# date after 2021-11-29 00:00:00
# date before 2021-11-30 00:00:00
# date after 2021-12-30 00:00:00
# date before 2021-12-31 00:00:00

# %% [markdown]
# ## Monthly loop

# %%
for m in range(1, 13):
    year = 2021
    yearAfter = year
    monthBefore = m
    monthAfter = m

    endMonthDate = 31
    
    if(m == 1) or (m == 3) or (m == 5) or (m == 7) or (m == 8) or (m == 10) or (m == 12):
        endMonthDate = 31
    elif(m == 2):
        endMonthDate = 28
    else: 
        endMonthDate = 30

    print('Month:', endMonthDate, '-', m, '- ', year)
# Out:
# Month: 31 - 1 -  2021
# Month: 28 - 2 -  2021
# Month: 31 - 3 -  2021
# Month: 30 - 4 -  2021
# Month: 31 - 5 -  2021
# Month: 30 - 6 -  2021
# Month: 31 - 7 -  2021
# Month: 31 - 8 -  2021
# Month: 30 - 9 -  2021
# Month: 31 - 10 -  2021
# Month: 30 - 11 -  2021
# Month: 31 - 12 -  2021

# %% [markdown]
# ## Hourly loop

# %%
# create the datetime object
date_time = dt.datetime(2016, 12, 31, 0, 0)

# loop over the next 24 hours
for i in range(24):
    # date_time = date_time + dt.timedelta(hours=1)
    time = dt.datetime(2016,12,21,i,0)
    print(time)
#     print(date_time)
# Out:
# 2016-12-21 00:00:00
# 2016-12-21 01:00:00
# 2016-12-21 02:00:00
# 2016-12-21 03:00:00
# 2016-12-21 04:00:00
# 2016-12-21 05:00:00
# 2016-12-21 06:00:00
# 2016-12-21 07:00:00
# 2016-12-21 08:00:00
# 2016-12-21 09:00:00
# 2016-12-21 10:00:00
# 2016-12-21 11:00:00
# 2016-12-21 12:00:00
# 2016-12-21 13:00:00
# 2016-12-21 14:00:00
# 2016-12-21 15:00:00
# 2016-12-21 16:00:00
# 2016-12-21 17:00:00
# 2016-12-21 18:00:00
# 2016-12-21 19:00:00
# 2016-12-21 20:00:00
# 2016-12-21 21:00:00
# 2016-12-21 22:00:00
# 2016-12-21 23:00:00

# %%
for m in range(1, 13):
    year = 2021
    yearAfter = year
    monthBefore = m
    monthAfter = m
        
    day = 32
    
    if (m == 2):
        day = 29
    if (m == 4) or (m == 6) or (m == 9) or (m == 11):
        day = 31
    
    for d in range(1, day):
        # loop through the dates :TODO

        # date variables
        dayBefore = d
        dayAfter = d-1

        # if current day is 1, then the previous day is the last day in previous month
        if(dayAfter == 0):
            monthAfter = m-1
            if(m == 2):
                dayAfter = 31
            elif(m==3):
                dayAfter = 28
            elif (m == 4) or (m == 6) or (m == 9) or (m == 11):
                dayAfter = 31
            else: dayAfter = 30
        else: monthAfter = m
            

        if(monthAfter == 0):
            print('hjello')
            continue
#             monthAfter = 12
#             yearAfter = year-1
#         else: yearAfter = year
            
        
        
        print('date after', dayAfter, '-', monthAfter, '- ', yearAfter)
        print('date before', dayBefore, '-', monthBefore, '- ', year)
# Out:
# hjello
# date after 1 - 1 -  2021
# date before 2 - 1 -  2021
# date after 2 - 1 -  2021
# date before 3 - 1 -  2021
# date after 3 - 1 -  2021
# date before 4 - 1 -  2021
# date after 4 - 1 -  2021
# date before 5 - 1 -  2021
# date after 5 - 1 -  2021
# date before 6 - 1 -  2021
# date after 6 - 1 -  2021
# date before 7 - 1 -  2021
# date after 7 - 1 -  2021
# date before 8 - 1 -  2021
# date after 8 - 1 -  2021
# date before 9 - 1 -  2021
# date after 9 - 1 -  2021
# date before 10 - 1 -  2021
# date after 10 - 1 -  2021
# date before 11 - 1 -  2021
# date after 11 - 1 -  2021
# date before 12 - 1 -  2021
# date after 12 - 1 -  2021
# date before 13 - 1 -  2021
# date after 13 - 1 -  2021
# date before 14 - 1 -  2021
# date after 14 - 1 -  2021
# date before 15 - 1 -  2021
# date after 15 - 1 -  2021
# date before 16 - 1 -  2021
# date after 16 - 1 -  2021
# date before 17 - 1 -  2021
# date after 17 - 1 -  2021
# date before 18 - 1 -  2021
# date after 18 - 1 -  2021
# ...
